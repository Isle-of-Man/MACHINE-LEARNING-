# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib import pyplot as plt
from sklearn import datasets #for dummy data

# %% [markdown]
# ### fzgsdfga

# %% [markdown]
# #### Difference between a good line and a perfect line

# %% [markdown]
# - waht are the criteria for a line ??
#     - distance
#     - sum of errors
#     - accuracy
#
# - of all the things mentioned above accuracy is wrong because for a good line and a best line accuracy will be same because both are classifying each accordingly
# - but what is the problem with accuracy if they both are doing the same job perfectly ??
#     - the issue is with historical data ie data that i already have - so if a point comes close to the line and we already know where it belongs but the line miss classifies it to another class and issue like this happens
#
# - error and distances are almost the same but for regression we use error and classification we use distance ir sistance os a point from the DB or half plane
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Distance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - mathematical notetion of data for Binary Classification
# - the question here is : given f(x) can we predict yi ie given the details of a fruit can we predict if its a tangerine or an orange
# ![image.png](attachment:image.png)
# - acuuracy is the closeness of the predicted output vs ground truth and perfecting that is the job of our model.

# %% [markdown]
# #### How to get the perfect line ??

# %% [markdown]
# - in the equation Wtx + w0 = 0 ; its evident that the line will change with changing the W vector and w0 which is the slope and intercept
# - so formulating the w and wo paramenters will be the best mothod to find the best line
# - the sum of distances from the DB should be maximum
# - distance formula from hplane is summation i =1 - n (wTx+ w0)/||W||
#     - THE ISSUE HERE IS - the value will be max -ve for lower half and max +ve for upper half points which is nice but what happens for miss classified points ??
#     - so a hack to this is take the distance and multiply the sign of the point to it and add. = distance * yi in fig
#     - the miss classified will have -ve and +ve which will be subtracted eventually but the correct classified will be maximized reducing the miss classified effects.
#     - ![image.png](attachment:image.png)

# %% [markdown]
# #### Problem setup we can explain to computer for the above explanation (LOSS FUCTION)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# - here we have xi which is present in the given dataset but what we dont have is W and W0 which we will take randomly select ; but the issue is we cant randomly do perm and comb of W and W0 to maximize it and for that  WE USE CLACULUS
#
#
#
# - 1 - what is maximize
#     - take one value of w and w0 and put it in equation with all possibilities of x and summation of which ever combination oif w and w0 is higher we take that w and w0
# - 2 - w and w0 possibilities
#     - randomly we have infinate possibilities so we use calculus

# %% [markdown]
# #### Calculus - LIMIT ( fundamental)

# %% [markdown]
# - some important fuction in ML
# - Domain is whatever we can input
# - Range is whatever we can output
# - R+ is range 0 to inf ie no negative values
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Use of Differentiation in ML

# %% [markdown]
# - we have to find the maxima or the minima and for that we use have to experiment with different W and W0's
# - since that is taking billions of possibilities we introduced differentiation.
# - Differentiation is useful because differentiation is the rate of change of slope
# - so the rate of change will be zero for a maxima or a minima because rate of change will be from -ve to 0 to +ve 4
# - Therefore the easiest way to find the point is equate the equation to zero for eg :
#     - take y = a - 4(x-b)^2
#     - f!(y) = 0 - 4*2 (x-b)
#     - maxima is at f!(y) = 0 ie 0 = 0 - 4*2 (x-b)
#     - x = b and sub x = b in y = a - 4(x-b)^2 we get y = a
#     - therefore the maxima is at (b,a)

# %% [markdown]
# ### Optimisation using Calculus

# %% [markdown]
# - at the point of inflection the rate of change wrt x will be zero.
# - in the below pictire there are multiple maximas and multiple minimas
# ![image.png](attachment:image.png)
